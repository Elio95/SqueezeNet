# %%
resize=227
squeezeratio1=4  
squeezeratio2=4

squeezeratio1_f1=6 #4  #6
squeezeratio2_f1=2 #4

squeezeratio1_f2=2 #4
squeezeratio2_f2=6 #4


dimratio=0.25 # vary this value 
dimration_=1  #try increasing this 

#count number of parameters 
# see accuracy 


squeezeplanes1=16
squeezeplanes2=32
squeezeplanes3=48
squeezeplanes4=64


dim1=squeezeplanes1
dim2=squeezeplanes2
dim3=squeezeplanes3
dim4=squeezeplanes4

dim1_f1=int(dim1*dimratio)
dim2_f1=int(dim2*dimratio)
dim3_f1=int(dim3*dimratio)
dim4_f1=int(dim4*dimratio)

dim1_f2=int(dim1*dimration_)
dim2_f2=int(dim2*dimration_)
dim3_f2=int(dim3*dimration_)
dim4_f2=int(dim4*dimration_)

# %%
import math
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.utils.model_zoo as model_zoo

# %%
__all__ = ['SqueezeNet', 'squeezenet1_0', 'squeezenet1_1']

# %%
model_urls = {
    'squeezenet1_0': 'https://download.pytorch.org/models/squeezenet1_0-a815701f.pth',
    'squeezenet1_1': 'https://download.pytorch.org/models/squeezenet1_1-f364aa15.pth',
}

# %%
class Fire(nn.Module):

    def __init__(self, inplanes, squeeze_planes,
                 expand1x1_planes, expand3x3_planes):
        super(Fire, self).__init__()
        self.inplanes = inplanes
        self.squeeze = nn.Conv2d(inplanes, squeeze_planes, kernel_size=1)
        
        
        self.squeeze_activation = nn.ReLU(inplace=True)
        self.expand1x1 = nn.Conv2d(squeeze_planes, expand1x1_planes,
                                   kernel_size=1)
        self.expand1x1_activation = nn.ReLU(inplace=True)
        self.expand3x3 = nn.Conv2d(squeeze_planes, expand3x3_planes,
                                   kernel_size=3, padding=1)
        self.expand3x3_activation = nn.ReLU(inplace=True)

    def forward(self, x):
        x = self.squeeze_activation(self.squeeze(x))
        return torch.cat([
            self.expand1x1_activation(self.expand1x1(x)),
            self.expand3x3_activation(self.expand3x3(x))
        ], 1)

# %%
class SqueezeNet(nn.Module):

    def __init__(self, version=1.0, num_classes=1000):
        super(SqueezeNet, self).__init__()
        if version not in [1.0, 1.1]:
            raise ValueError("Unsupported SqueezeNet version {version}:"
                             "1.0 or 1.1 expected".format(version=version))
        self.num_classes = num_classes
        if version == 1.0:
            self.features = nn.Sequential(
                nn.Conv2d(3, 96,kernel_size=7, stride=2),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                #dim1=16
                Fire(96, dim1_f1, squeezeratio1_f1*dim1_f1, squeezeratio2_f1*dim1_f1),
                Fire(squeezeratio1_f1*dim1_f1+squeezeratio2_f1*dim1_f1, dim1_f2, squeezeratio1_f2*dim1_f2, squeezeratio2_f2*dim1_f2),
                
                
                
                
                #dim2=32
                Fire(squeezeratio1_f2*dim1_f2+squeezeratio2_f2*dim1_f2, dim2_f1, squeezeratio1_f1*dim2_f1, squeezeratio2_f1*dim2_f1),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(squeezeratio1_f1*dim2_f1+squeezeratio2_f1*dim2_f1, dim2_f2, squeezeratio1_f2*dim2_f2, squeezeratio2_f2*dim2_f2),
                
                
                #dim3=48
                Fire(squeezeratio1_f2*dim2_f2+squeezeratio2_f2*dim2_f2, dim3_f1, squeezeratio1_f1*dim3_f1, squeezeratio2_f1*dim3_f1),
                Fire(squeezeratio1_f1*dim3_f1+squeezeratio2_f1*dim3_f1, dim3_f2, squeezeratio1_f2*dim3_f2, squeezeratio2_f2*dim3_f2),
                
                #dim4=64
                Fire(squeezeratio1_f2*dim3_f2+squeezeratio2_f2*dim3_f2, dim4_f1, squeezeratio1_f1*dim4_f1, squeezeratio2_f1*dim4_f1),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(squeezeratio1_f1*dim4_f1+squeezeratio2_f1*dim4_f1, dim4_f2, squeezeratio1_f2*dim4_f2, squeezeratio2_f2*dim4_f2),
            )
        else:
            self.features = nn.Sequential(
                nn.Conv2d(3, 64, kernel_size=3, stride=2),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(64, 16, 64, 64),
                Fire(128, 16, 64, 64),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(128, 32, 128, 128),
                Fire(256, 32, 128, 128),
                nn.MaxPool2d(kernel_size=3, stride=2, ceil_mode=True),
                Fire(256, 48, 192, 192),
                Fire(384, 48, 192, 192),
                Fire(384, 64, 256, 256),
                Fire(512, 64, 256, 256),
            )
        # Final convolution is initialized differently form the rest
        final_conv = nn.Conv2d(squeezeratio1_f2*dim4_f2+squeezeratio2_f2*dim4_f2, self.num_classes, kernel_size=1)
        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5),
            final_conv,
            nn.ReLU(inplace=True),
            nn.AvgPool2d(13, stride=1)
        )

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                if m is final_conv:
                    init.normal(m.weight.data, mean=0.0, std=0.01)
                else:
                    init.kaiming_uniform(m.weight.data)
                if m.bias is not None:
                    m.bias.data.zero_()

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x.view(x.size(0), self.num_classes)

# %%
def squeezenet1_0(pretrained=False, **kwargs):
    r"""SqueezeNet model architecture from the `"SqueezeNet: AlexNet-level
    accuracy with 50x fewer parameters and <0.5MB model size"
    <https://arxiv.org/abs/1602.07360>`_ paper.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
    """
    model = SqueezeNet(version=1.0, **kwargs)
    if pretrained:
        model.load_state_dict(model_zoo.load_url(model_urls['squeezenet1_0']))
    return model

# %%
model=squeezenet1_0(pretrained=False,num_classes=10).cuda()
# total parameters
pytorch_total_params = sum(p.numel() for p in model.parameters())
pytorch_total_params
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:68: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:66: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# 488722

# %%
#CIFAR10 squeezenet 

import torchvision.datasets as datasets
import torchvision.transforms as transforms


#model=alexnet(pretrained=False,num_classes=10).cuda()
model=squeezenet1_0(pretrained=False,num_classes=10).cuda()




#dataiter = iter(testloader)
#images, labels = dataiter.next()
#outputs = model(images.cuda())
#outputs = model(images)

def evaluate(model):
  correct = 0
  total = 0
  with torch.no_grad():
      for data in testloader:
          images, labels = data
          outputs = model(images.cuda())
          #outputs = model(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels.cuda()).sum().item()
          #correct += (predicted == labels).sum().item()
  print('Accuracy of the network on the 10000 test images: %d %%' % (
      100 * correct / total))

  acc= 100 * correct / total







import torch
import torchvision
import torchvision.transforms as transforms

#transform1
transform = transforms.Compose(
    [#transforms.Resize((32,32)), #kept to orignal size 
     
     transforms.ToTensor(),
     
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
     #transforms.Normalize((0.4914, 0.4822, 0.4465), (0.247, 0.243, 0.261))
     ])


#transform2 (transform_train)



transform = transforms.Compose([
    transforms.Resize((resize,resize)),
    transforms.RandomCrop(resize, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])



transformtest=transforms.Compose([
    transforms.Resize((resize,resize)),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)



trainloader = torch.utils.data.DataLoader(trainset, batch_size=128,
                                          shuffle=True, num_workers=2)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transformtest)
testloader = torch.utils.data.DataLoader(testset, batch_size=1,
                                         shuffle=False, num_workers=2)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
import matplotlib.pyplot as plt
import numpy as np


import torch.optim as optim

criterion = nn.CrossEntropyLoss()
#criterion = nn.MSELoss()
#optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9,weight_decay=5e-4)
optimizer = optim.Adam(model.parameters())
n=0
optimizer.zero_grad()


for epoch in range(100):  # loop over the dataset multiple times

    running_loss = 0.0
    print(epoch)
    evaluate(model)
    for i, data in enumerate(trainloader, 0):
        # get the inputs
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = model(inputs.cuda())
        loss = criterion(outputs.cuda(), labels.cuda())
        loss.backward()
        optimizer.step()
        #print(i)
        
        
        # print statistics
        running_loss += loss.item()
        if i % 2000 == 1999:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / 2000))
            running_loss = 0.0
            
    

print('Finished Training')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:68: UserWarning: nn.init.kaiming_uniform is now deprecated in favor of nn.init.kaiming_uniform_.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:66: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Files already downloaded and verified
# Files already downloaded and verified
# 0
# Accuracy of the network on the 10000 test images: 10 %
# 1
# Accuracy of the network on the 10000 test images: 24 %
# 2
# Accuracy of the network on the 10000 test images: 35 %
# 3
# Accuracy of the network on the 10000 test images: 39 %
# 4
# Accuracy of the network on the 10000 test images: 40 %
# 5
# Accuracy of the network on the 10000 test images: 46 %
# 6
# Accuracy of the network on the 10000 test images: 56 %
# 7
# Accuracy of the network on the 10000 test images: 57 %
# 8
# Accuracy of the network on the 10000 test images: 61 %
# 9
# Accuracy of the network on the 10000 test images: 64 %
# 10
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
model_save_name = 'test_firesqueeze_25epochs76percentacc.pt'
PATH = F"/content/gdrive/My Drive/{model_save_name}" 
torch.save(model.state_dict(), PATH)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
